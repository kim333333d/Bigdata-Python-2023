# %% [markdown]
# #### 데이터 전처리 및 시각화
#
# ##### 전처리
# 데이터프레임 병합

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\program files\python311\lib\site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in c:\program files\python311\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in c:\program files\python311\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\program files\python311\lib\site-packages (from folium) (1.25.0)
# Requirement already satisfied: requests in c:\program files\python311\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\program files\python311\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\python311\lib\site-packages (from requests->folium) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\python311\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\python311\lib\site-packages (from requests->folium) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\python311\lib\site-packages (from requests->folium) (2023.5.7)

# %%
# import
import pandas as pd
import numpy as np

import folium
import json

# %%
# 스타벅스 매장리스트
sbuck_df = pd.read_excel('./seoul_starbuks.xlsx', header=0)
sbuck_df.head()
# Out:
#        매장명         위도          경도     매장타입                          주소
# 0  역삼아레나빌딩  37.501087  127.043069  general     서울특별시 강남구 언주로 425 (역삼동)
# 1   논현역사거리  37.510178  127.022223  general    서울특별시 강남구 강남대로 538 (논현동)
# 2  신사역성일빌딩  37.513931  127.020606  general    서울특별시 강남구 강남대로 584 (논현동)
# 3   국기원사거리  37.499517  127.031495  general    서울특별시 강남구 테헤란로 125 (역삼동)
# 4  대치재경빌딩R  37.494668  127.062583  reserve  서울특별시 강남구 남부순환로 2947 (대치동)

# %%
sbuck_df['주소'][599].split()[1]
# Out:
# '중랑구'

# %%
gu_list = []
for item in sbuck_df['주소']:
    gu = item.split()[1]
    gu_list.append(gu)

sbuck_df['구'] = gu_list
sbuck_df.tail()
# Out:
#       매장명         위도          경도     매장타입  \
# 595  사가정역  37.579594  127.087966  general
# 596   상봉역  37.596890  127.086470  general
# 597    묵동  37.615368  127.076633  general
# 598   양원역  37.606654  127.106360  general
# 599   중화역  37.601709  127.078411  general
#
#                                         주소    구
# 595                      서울특별시 중랑구 면목로 310  중랑구
# 596                서울특별시 중랑구 망우로 307 (상봉동)  중랑구
# 597  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  중랑구
# 598              서울특별시 중랑구 양원역로10길 3 (망우동)  중랑구
# 599                     서울특별시 중랑구 봉화산로 35   중랑구

# %% [markdown]
# ##### 서울시 행정구역별 위경도 전처리
#
# - 대한민국 행정구역 위경도엑셀파일에서 서울만 필터링

# %%
seoul_loc_df = pd.read_excel('./대한민국_행정구역_위경도.xlsx')
seoul_loc_df.head()
# Out:
#   docity  do city   longitude   latitude
# 0  강원강릉시  강원  강릉시  128.878497  37.749136
# 1  강원고성군  강원  고성군  128.470164  38.377961
# 2  강원동해시  강원  동해시  129.116633  37.521931
# 3  강원삼척시  강원  삼척시  129.167489  37.447086
# 4  강원속초시  강원  속초시  128.594167  38.204275

# %%
seoul_gu_df = seoul_loc_df[seoul_loc_df['do'] == '서울']
seoul_gu_df.head()
# Out:
#     docity  do city   longitude   latitude
# 138  서울강남구  서울  강남구  127.049556  37.514575
# 139  서울강동구  서울  강동구  127.125864  37.527367
# 140  서울강북구  서울  강북구  127.027719  37.636956
# 141  서울강서구  서울  강서구  126.851675  37.548156
# 142  서울관악구  서울  관악구  126.953844  37.475386

# %%
seoul_gu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 138 to 162
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   docity     25 non-null     object
#  1   do         25 non-null     object
#  2   city       25 non-null     object
#  3   longitude  25 non-null     float64
#  4   latitude   25 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 1.2+ KB

# %%
seoul_gu_df.to_excel('./seoul_gu_info.xlsx', index=False)

# %% [markdown]
# ##### 서울시 구별 스타번스 매장수 구하기

# %%
sbuck_gu_counts= sbuck_df.pivot_table(index='구',
                                      values='매장명',
                                      aggfunc='count').rename(columns= {'매장명': '스타벅스_매장수'})
sbuck_gu_counts.head()
# Out:
#      스타벅스_매장수
# 구
# 강남구        88
# 강동구        17
# 강북구         6
# 강서구        25
# 관악구        11

# %%
# seoul_gu_df 수정
seoul_gu_df = seoul_gu_df[['do', 'city', 'latitude', 'longitude']]
columns = {'do':'도', 'city':'구', 'latitude':'위도', 'longitude':'경도'}
seoul_gu_df.rename(columns=columns, inplace=True)
seoul_gu_df.reset_index(drop=True, inplace=True)

# %%
seoul_gu_df = seoul_gu_df[['도', '구', '경도', '위도']]
seoul_gu_df.reset_index(drop=True, inplace=True)

# %%
seoul_gu_df.head()
# Out:
#     도    구          경도         위도
# 0  서울  강남구  127.049556  37.514575
# 1  서울  강동구  127.125864  37.527367
# 2  서울  강북구  127.027719  37.636956
# 3  서울  강서구  126.851675  37.548156
# 4  서울  관악구  126.953844  37.475386

# %%
seoul_sgg = pd.merge(seoul_gu_df, sbuck_gu_counts, how='left', on='구')
seoul_sgg
# Out:
#      도     구          경도         위도  스타벅스_매장수
# 0   서울   강남구  127.049556  37.514575        88
# 1   서울   강동구  127.125864  37.527367        17
# 2   서울   강북구  127.027719  37.636956         6
# 3   서울   강서구  126.851675  37.548156        25
# 4   서울   관악구  126.953844  37.475386        11
# 5   서울   광진구  127.084533  37.535739        18
# 6   서울   구로구  126.889597  37.492650        14
# 7   서울   금천구  126.904197  37.449108        12
# 8   서울   노원구  127.058389  37.651461        14
# 9   서울   도봉구  127.049522  37.665833         5
# 10  서울  동대문구  127.042142  37.571625        10
# 11  서울   동작구  126.941575  37.509656        11
# 12  서울   마포구  126.910531  37.560706        36
# 13  서울  서대문구  126.938897  37.576367        22
# 14  서울   서초구  127.034811  37.480786        49
# 15  서울   성동구  127.039000  37.560611        14
# 16  서울   성북구  127.020333  37.586383        15
# 17  서울   송파구  127.107931  37.511756        36
# 18  서울   양천구  126.868708  37.514231        17
# 19  서울  영등포구  126.898342  37.523611        41
# 20  서울   용산구  126.967522  37.536094        25
# 21  서울   은평구  126.931242  37.599969        13
# 22  서울   종로구  126.981642  37.570378        40
# 23  서울    중구  126.999642  37.561003        53
# 24  서울   중랑구  127.094778  37.603806         8

# %%
seoul_pop = pd.read_excel('./seoul_pop.xlsx')
seoul_pop.tail()
# Out:
#       구       계
# 20  관악구  502628
# 21  서초구  408979
# 22  강남구  537817
# 23  송파구  663704
# 24  강동구  464027

# %%
seoul_sgg = pd.merge(seoul_sgg, seoul_pop, how='left', on='구')
seoul_sgg.head()
# Out:
#     도    구          경도         위도  스타벅스_매장수       계
# 0  서울  강남구  127.049556  37.514575        88  537817
# 1  서울  강동구  127.125864  37.527367        17  464027
# 2  서울  강북구  127.027719  37.636956         6  296934
# 3  서울  강서구  126.851675  37.548156        25  573711
# 4  서울  관악구  126.953844  37.475386        11  502628

# %%
seoul_sgg = seoul_sgg[['도','구','경도','위도','스타벅스_매장수','계']]
seoul_sgg.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 seoul_sgg = seoul_sgg[['도','구','경도','위도','스타벅스_매장수','계_x']]
#       2 seoul_sgg.tail()
#
# File c:\Program Files\Python311\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Program Files\Python311\Lib\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File c:\Program Files\Python311\Lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['계_x'] not in index"

# %%
# 사업체수
seoul_biz = pd.read_excel('./seoul_biz.xlsx')
seoul_biz.tail()
# Out:
#       구    사업체수   종사자수계
# 20  관악구   37915  128417
# 21  서초구   71958  487976
# 22  강남구  110007  801419
# 23  송파구   74531  400781
# 24  강동구   41660  157465

# %%
seoul_sgg_stat = pd.merge(seoul_sgg, seoul_biz, how='left', on='구')
seoul_sgg_stat.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 seoul_sgg_stat = pd.merge(seoul_sgg, seoul_biz, how='left', on='구')
#       2 seoul_sgg_stat.tail()
#
# NameError: name 'seoul_biz' is not defined

# %%
columns = {'도':'도','구':'구','경도':'경도','위도':'위도','스타벅스_매장수':'스타벅스_매장수',
           '계_x':'인구수','사업체수':'사업체수','종사자수계':'종사자수'}
seoul_sgg_stat.rename(columns=columns, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 3
#       1 columns = {'도':'도','구':'구','경도':'경도','위도':'위도','스타벅스_매장수':'스타벅스_매장수',
#       2            '계_x':'인구수','사업체수':'사업체수','종사자수계':'종사자수'}
# ----> 3 seoul_sgg_stat.rename(columns=columns, inplace=True)
#
# NameError: name 'seoul_sgg_stat' is not defined

# %%
seoul_sgg_stat.to_excel('./seoul_sgg_stat.xlsx', index=False)

# %% [markdown]
# ##### 데이터 시각화

# %%
sbuck_df.tail()
# Out:
#       매장명         위도          경도     매장타입  \
# 595  사가정역  37.579594  127.087966  general
# 596   상봉역  37.596890  127.086470  general
# 597    묵동  37.615368  127.076633  general
# 598   양원역  37.606654  127.106360  general
# 599   중화역  37.601709  127.078411  general
#
#                                         주소    구
# 595                      서울특별시 중랑구 면목로 310  중랑구
# 596                서울특별시 중랑구 망우로 307 (상봉동)  중랑구
# 597  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  중랑구
# 598              서울특별시 중랑구 양원역로10길 3 (망우동)  중랑구
# 599                     서울특별시 중랑구 봉화산로 35   중랑구

# %%
sbuck_map = folium.Map(location=[37.550823, 126.989502], tiles='Stamen Terrain', zoom_start=11)

for idx in sbuck_df.index:
    lat = sbuck_df.loc[idx, '위도']
    lng = sbuck_df.loc[idx, '경도']
    name = sbuck_df.loc[idx, '매장명']

    folium.CircleMarker(location=[lat, lng], fill=True, fill_color='green', fill_opacity=1, popup=name,
                        color='yellow', weight=1, radius=3).add_to(sbuck_map)

sbuck_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65c2926d85dacc3bd9fa488e68dbae76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65c2926d85dacc3bd9fa488e68dbae76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65c2926d85dacc3bd9fa488e68dbae76 = L.map(
#                 &quot;map_65c2926d85dacc3bd9fa488e68dbae76&quot;,
#                 {
#                     center: [37.550823, 126.989502],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e049887fdce74667b83e10c7cecf40c4 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_65c2926d85dacc3bd9fa488e68dbae76);
#
#
#             var circle_marker_e9431c52a86698fd71fbd6c7273ddb93 = L.circleMarker(
#                 [37.501087, 127.043069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_65c2926d85dacc3bd9fa488e68dbae76);
#
#
#         var popup_e577b9911fa1c6b54cd3d0b68b24070f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_462a4f3619f9d6ef1a36d1516458b9e7 = $(`&lt;div id=&quot;html_462a4f3619f9d6ef1a36d1516458b9e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;역삼아레나빌딩&lt;/div&gt;`)[0];
#                 popup_e577b9911fa1c6b54cd3d0b68b24070f.setContent(html_462a4f3619f9d6ef1a36d1516458b9e7);
#
#
#
#         circle_marker_e9431c52a86698fd71fbd6c7273ddb93.bindPopup(popup_e577b9911fa1c6b54cd3d0b68b24070f)
#         ;
#
#
#
#
#             var circle_marker_98b381eb213167e3b8a6168e4ead73bc = L.circleMarker(
#                 [37.510178, 127.022223],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_65c2926d85dacc3bd9fa488e68dbae76);
#
#
#         var popup_d1d0457e3ceb07e10b600e6ab250feb9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95e867bd185bec351a368c10da9b29ed = $(`&lt;div id=&quot;html_95e867bd185bec351a368c10da9b29ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;논현역사거리&lt;/div&gt;`)[0];
#                 popup_d1d0457e3ceb07e10b600e6ab250feb9.setContent(html_95e867bd185bec351a368c10da9b29ed);
#
#
#
#         circle_marker_98b381eb213167e3b8a6168e4ead73bc.bindPopup(popup_d1d0457e3ceb07e10b600e6ab250feb9)
#         ;
#
#
#
#
#             var circle_marker_590bf737c7942f982975e471d2500cb3 = L.circleMarker(
#                 [37.5139309, 127.0206057],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_65c2926d85dacc3bd9fa488e68dbae76);
#
#
#         var popup_395f25be623a54359162f720d6f79b49 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_33d21a0ffcaa2827dc017ed7bbe4be08 = $(`&lt;div id=&quot;html_33d21a0ffcaa2827dc017ed7bbe4be08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신사역성일빌딩&lt;/div&gt;`)[0];
#                 popup_395f25be623a54359162f720d6f79b49.setContent(html_33d21a0ffcaa2827dc017ed7bbe4be08);
#
#
#
#         circle_marker_590bf737c7942f982975e471d2500cb3.bindPopup(popup_395f25be623a54359162f720d6f79b49)
#         ;
#
#
#
#
#             var circle_marke

# %%
sbuck_map2 = folium.Map(location=[37.550823, 126.989502], tiles='Stamen Terrain', zoom_start=11)

for idx in sbuck_df.index:
    lat = sbuck_df.loc[idx, '위도']
    lng = sbuck_df.loc[idx, '경도']
    name = sbuck_df.loc[idx, '매장명']
    type = sbuck_df.loc[idx, '매장타입']

    # 매장타입별 색상
    fillcolor = ''
    size = 2
    if type == 'general':
        fillcolor = 'gray'
        size = 2
    elif type == 'reserve':
        fillcolor = 'black'
        size = 5
    elif type == 'generalDT':
        fillcolor = 'red'
        size = 3
    elif type == 'generalWT':
        fillcolor = 'blue'
        size = 3

    folium.CircleMarker(location=[lat, lng], fill=True, fill_color=fillcolor, fill_opacity=1, popup=name,
                        color='yellow', weight=1, radius=size).add_to(sbuck_map2)

sbuck_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3066578d7fbe1221d417b5b723ba4dad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3066578d7fbe1221d417b5b723ba4dad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3066578d7fbe1221d417b5b723ba4dad = L.map(
#                 &quot;map_3066578d7fbe1221d417b5b723ba4dad&quot;,
#                 {
#                     center: [37.550823, 126.989502],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_301df10b8b56b907d4faf7ca977c5f91 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3066578d7fbe1221d417b5b723ba4dad);
#
#
#             var circle_marker_3f0db216bcd8d5216846777808150a1e = L.circleMarker(
#                 [37.501087, 127.043069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_3066578d7fbe1221d417b5b723ba4dad);
#
#
#         var popup_5905a0d3e371d214827b915871df3cd9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03b72a629494932bdfb43a12077d7a08 = $(`&lt;div id=&quot;html_03b72a629494932bdfb43a12077d7a08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;역삼아레나빌딩&lt;/div&gt;`)[0];
#                 popup_5905a0d3e371d214827b915871df3cd9.setContent(html_03b72a629494932bdfb43a12077d7a08);
#
#
#
#         circle_marker_3f0db216bcd8d5216846777808150a1e.bindPopup(popup_5905a0d3e371d214827b915871df3cd9)
#         ;
#
#
#
#
#             var circle_marker_b905c2fd96487d302ed25949ada36ac7 = L.circleMarker(
#                 [37.510178, 127.022223],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_3066578d7fbe1221d417b5b723ba4dad);
#
#
#         var popup_24137c94e45c9f271bc7ba922a8ea574 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8c3e533f244af5c397103572706b240 = $(`&lt;div id=&quot;html_c8c3e533f244af5c397103572706b240&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;논현역사거리&lt;/div&gt;`)[0];
#                 popup_24137c94e45c9f271bc7ba922a8ea574.setContent(html_c8c3e533f244af5c397103572706b240);
#
#
#
#         circle_marker_b905c2fd96487d302ed25949ada36ac7.bindPopup(popup_24137c94e45c9f271bc7ba922a8ea574)
#         ;
#
#
#
#
#             var circle_marker_34da50fd8ff5ac9cea95af3b76a7b389 = L.circleMarker(
#                 [37.5139309, 127.0206057],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_3066578d7fbe1221d417b5b723ba4dad);
#
#
#         var popup_1f5cf6d5c7924ac4f0db6590b485d72e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6170645cf69a3e77fe19d95b8bc2d872 = $(`&lt;div id=&quot;html_6170645cf69a3e77fe19d95b8bc2d872&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신사역성일빌딩&lt;/div&gt;`)[0];
#                 popup_1f5cf6d5c7924ac4f0db6590b485d72e.setContent(html_6170645cf69a3e77fe19d95b8bc2d872);
#
#
#
#         circle_marker_34da50fd8ff5ac9cea95af3b76a7b389.bindPopup(popup_1f5cf6d5c7924ac4f0db6590b485d72e)
#         ;
#
#
#
#
#             var circle_marker_6

# %%
# 시군구경계표시
sgg_geojson_path = './seoul_geo_simple.json'
seoul_sgg_geo = json.load(open(sgg_geojson_path, encoding='utf-8'))

sbuck_map3 = folium.Map(location=[37.550823, 126.989502], tiles='CartoDB dark_matter', zoom_start=11)

folium.GeoJson(seoul_sgg_geo, name='Seoul행정구역').add_to(sbuck_map3)

sbuck_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aff77d446dba1d1e5d31ca270fb969a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aff77d446dba1d1e5d31ca270fb969a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aff77d446dba1d1e5d31ca270fb969a3 = L.map(
#                 &quot;map_aff77d446dba1d1e5d31ca270fb969a3&quot;,
#                 {
#                     center: [37.550823, 126.989502],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50683575ec9d56d89e32cb492a6a2458 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aff77d446dba1d1e5d31ca270fb969a3);
#
#
#
#         function geo_json_1e3d50c224a19863614bb3e0ae0116fc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1e3d50c224a19863614bb3e0ae0116fc = L.geoJson(null, {
#                 onEachFeature: geo_json_1e3d50c224a19863614bb3e0ae0116fc_onEachFeature,
#
#         });
#
#         function geo_json_1e3d50c224a19863614bb3e0ae0116fc_add (data) {
#             geo_json_1e3d50c224a19863614bb3e0ae0116fc
#                 .addData(data)
#                 .addTo(map_aff77d446dba1d1e5d31ca270fb969a3);
#         }
#             geo_json_1e3d50c224a19863614bb3e0ae0116fc_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069754405746], [127.14980119646964, 37.50046502392898], [127.15223804785649, 37.50170492532197], [127.15401160147654, 37.500347919909956], [127.16086308579277, 37.49886565522751], [127.1634944215765, 37.497445406097484], [127.16199885180917, 37.49402577547199], [127.162

# %%
sbuck_mean = seoul_sgg_stat['스타벅스_매장수'].mean()
sbuck_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 sbuck_mean = seoul_sgg_stat['스타벅스_매장수'].mean()
#       2 sbuck_mean
#
# NameError: name 'seoul_sgg_stat' is not defined

# %%
# 시군구경계표시
sgg_geojson_path = './seoul_geo_simple.json'
seoul_sgg_geo = json.load(open(sgg_geojson_path, encoding='utf-8'))

sbuck_map3 = folium.Map(location=[37.550823, 126.989502], tiles='CartoDB dark_matter', zoom_start=11)

folium.GeoJson(seoul_sgg_geo, name='Seoul행정구역').add_to(sbuck_map3)

for idx in seoul_sgg_stat.index:
    lat = seoul_sgg_stat.loc[idx, '위도']
    lng = seoul_sgg_stat.loc[idx, '경도']
    count = seoul_sgg_stat.loc[idx, '스타벅스_매장수']

    if count > sbuck_mean: # 구별 평균치보다 매장수가 많음
        fillcolor = 'red'
    else:
        fillcolor = 'blue'

    folium.CircleMarker(location=[lat, lng], color='#ffff00', fill_color=fillcolor, fill_opacity=0.7, weight=1.5, radius=count/2, popup=count).add_to(sbuck_map3)

sbuck_map3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 9
#       5 sbuck_map3 = folium.Map(location=[37.550823, 126.989502], tiles='CartoDB dark_matter', zoom_start=11)
#       7 folium.GeoJson(seoul_sgg_geo, name='Seoul행정구역').add_to(sbuck_map3)
# ----> 9 for idx in seoul_sgg_stat.index:
#      10     lat = seoul_sgg_stat.loc[idx, '위도']
#      11     lng = seoul_sgg_stat.loc[idx, '경도']
#
# NameError: name 'seoul_sgg_stat' is not defined

# %%
# 시군구경계표시
sgg_geojson_path = './seoul_geo_simple.json'
seoul_sgg_geo = json.load(open(sgg_geojson_path, encoding='utf-8'))

sbuck_map4 = folium.Map(location=[37.550823, 126.989502], tiles='CartoDB dark_matter', zoom_start=10)

folium.GeoJson(seoul_sgg_geo, name='Seoul행정구역').add_to(sbuck_map4)

folium.Choropleth(
    geo_data=seoul_sgg_geo,
    data=seoul_sgg_stat,
    columns=['구', '스타벅스_매장수'],
    fill_color='Purples', # YlGn, RdYlGn, Spectral, Accent, Reds, Greens, Blues, Oranges, Purples, Greys, PuOr, OrRd
    fill_opacity=0.7, 
    line_opacity=0.5,
    key_on='properties.name', # 이게 핵심 - key값이 없으면 지도에 색상표시 못함
).add_to(sbuck_map4)

sbuck_map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2d497fca7916a02d2a687bf7b10948d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2d497fca7916a02d2a687bf7b10948d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2d497fca7916a02d2a687bf7b10948d = L.map(
#                 &quot;map_f2d497fca7916a02d2a687bf7b10948d&quot;,
#                 {
#                     center: [37.550823, 126.989502],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c8567686e4be6eae0b7c288418ef237 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f2d497fca7916a02d2a687bf7b10948d);
#
#
#
#         function geo_json_ae44ef19276b2db97d5b9bd514acee93_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ae44ef19276b2db97d5b9bd514acee93 = L.geoJson(null, {
#                 onEachFeature: geo_json_ae44ef19276b2db97d5b9bd514acee93_onEachFeature,
#
#         });
#
#         function geo_json_ae44ef19276b2db97d5b9bd514acee93_add (data) {
#             geo_json_ae44ef19276b2db97d5b9bd514acee93
#                 .addData(data)
#                 .addTo(map_f2d497fca7916a02d2a687bf7b10948d);
#         }
#             geo_json_ae44ef19276b2db97d5b9bd514acee93_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.53572787912298], [127.12061313033807, 37.538129867839416], [127.1116764203608, 37.540669955324965], [127.11418412219375, 37.54474592090681], [127.11600200349189, 37.55053147511706], [127.11600943681239, 37.55580061507081], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.07496309841329, 37.52091052765938], [127.07968915919895, 37.52077294752823], [127.08639455667742, 37.52161824624356], [127.0943611414465, 37.523984206117525], [127.10087519791962, 37.524841220167055], [127.10484130265957, 37.53120327509912], [127.1116764203608, 37.540669955324965], [127.12061313033807, 37.538129867839416], [127.12532464331997, 37.53572787912298], [127.12251496040881, 37.52751810228347], [127.12123165719615, 37.52528270089], [127.14532023498624, 37.51464060108829], [127.14672806823502, 37.51415680680291], [127.14670263739373, 37.512786602955565], [127.14462782318448, 37.511529542030715], [127.14323992504048, 37.50951977457089], [127.1420864475393, 37.50578973782813], [127.14324986168657, 37.502649431479774], [127.1473517108062, 37.50069754405746], [127.14980119646964, 37.50046502392898], [127.15223804785649, 37.50170492532197], [127.15401160147654, 37.500347919909956], [127.16086308579277, 37

# %%
seoul_pop_coroplate = folium.Map(location=[37.550823, 126.989502], tiles='CartoDB dark_matter', zoom_start=10)

folium.Choropleth(geo_data = seoul_sgg_geo, data= seoul_sgg_stat, columns =['구', '인구수'], fill= 'purples', fill_opacity=0.7, line_opacity=0.5,
                   key_on='properties.name'.add_to(seoul_pop_coroplate))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 3
#       1 seoul_pop_coroplate = folium.Map(location=[37.550823, 126.989502], tiles='CartoDB dark_matter', zoom_start=10)
# ----> 3 folium.Choropleth(geo_data = seoul_sgg_geo, data= seoul_sgg_stat, columns =['구', '인구수'], fill= 'purples', fill_opacity=0.7, line_opacity=0.5,
#       4                    key_on='properties.name'.add_to(seoul_pop_coroplate))
#
# NameError: name 'seoul_sgg_stat' is not defined
